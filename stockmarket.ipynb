# %%
# import pandas_datareader.data as web  #importing required modules to condct analysis
import quandl
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import yfinance as yf
plt.style.use('ggplot')

# %%
# start = dt.datetime(2010,1,1)
# end = dt.datetime(2020,1,1)

# %%
boeing = quandl.get('WIKI/BA')  # pulling data for boeing
boeing.head()

# facebook.head()
# symbol = 'WMT'  #symbol for boeing
# source = 'yahoo'  #where the data is coming from
# boeing = web.DataReader(symbol, source, start, end)
# Out:
#              Open     High    Low  Close      Volume  Ex-Dividend  \
# Date
# 2010-06-29  19.00  25.0000  17.54  23.89  18766300.0          0.0
# 2010-06-30  25.79  30.4192  23.30  23.83  17187100.0          0.0
# 2010-07-01  25.00  25.9200  20.27  21.96   8218800.0          0.0
# 2010-07-02  23.00  23.1000  18.71  19.20   5139800.0          0.0
# 2010-07-06  20.00  20.0000  15.83  16.11   6866900.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  \
# Date
# 2010-06-29          1.0      19.00    25.0000     17.54       23.89
# 2010-06-30          1.0      25.79    30.4192     23.30       23.83
# 2010-07-01          1.0      25.00    25.9200     20.27       21.96
# 2010-07-02          1.0      23.00    23.1000     18.71       19.20
# 2010-07-06          1.0      20.00    20.0000     15.83       16.11
#
#             Adj. Volume
# Date
# 2010-06-29   18766300.0
# 2010-06-30   17187100.0
# 2010-07-01    8218800.0
# 2010-07-02    5139800.0
# ...

# %%
print(boeing.columns)  # viewing all the present columns in each dataframe
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Ex-Dividend', 'Split Ratio',
#        'Adj. Open', 'Adj. High', 'Adj. Low', 'Adj. Close', 'Adj. Volume'],
#       dtype='object')

# %%
walmart = quandl.get('WIKI/WMT')  # pulling data for walmart
walmart.head()
# Out:
#              Open   High    Low  Close  Volume  Ex-Dividend  Split Ratio  \
# Date
# 1972-08-25  32.50  33.13  32.50  33.00  4900.0          0.0          1.0
# 1972-08-28  33.00  33.25  32.88  32.88  1900.0          0.0          1.0
# 1972-08-29  32.75  32.75  32.50  32.50  3800.0          0.0          1.0
# 1972-08-30  32.50  32.50  32.25  32.50   800.0          0.0          1.0
# 1972-08-31  32.25  32.25  32.00  32.00  1700.0          0.0          1.0
#
#             Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
# Date
# 1972-08-25   0.043162   0.043999  0.043162    0.043826    2508800.0
# 1972-08-28   0.043826   0.044158  0.043667    0.043667     972800.0
# 1972-08-29   0.043494   0.043494  0.043162    0.043162    1945600.0
# 1972-08-30   0.043162   0.043162  0.042830    0.043162     409600.0
# 1972-08-31   0.042830   0.042830  0.042498    0.042498     870400.0

# %%
tesla = quandl.get('WIKI/TSLA')  # pulling data for tesla
tesla.head()
# Out:
#              Open     High    Low  Close      Volume  Ex-Dividend  \
# Date
# 2010-06-29  19.00  25.0000  17.54  23.89  18766300.0          0.0
# 2010-06-30  25.79  30.4192  23.30  23.83  17187100.0          0.0
# 2010-07-01  25.00  25.9200  20.27  21.96   8218800.0          0.0
# 2010-07-02  23.00  23.1000  18.71  19.20   5139800.0          0.0
# 2010-07-06  20.00  20.0000  15.83  16.11   6866900.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  \
# Date
# 2010-06-29          1.0      19.00    25.0000     17.54       23.89
# 2010-06-30          1.0      25.79    30.4192     23.30       23.83
# 2010-07-01          1.0      25.00    25.9200     20.27       21.96
# 2010-07-02          1.0      23.00    23.1000     18.71       19.20
# 2010-07-06          1.0      20.00    20.0000     15.83       16.11
#
#             Adj. Volume
# Date
# 2010-06-29   18766300.0
# 2010-06-30   17187100.0
# 2010-07-01    8218800.0
# 2010-07-02    5139800.0
# ...

# %%
facebook = quandl.get('WIKI/FB') # pulling dat for meta
facebook.head()
# Out:
#              Open   High    Low    Close       Volume  Ex-Dividend  \
# Date
# 2012-05-18  42.05  45.00  38.00  38.2318  573576400.0          0.0
# 2012-05-21  36.53  36.66  33.00  34.0300  168192700.0          0.0
# 2012-05-22  32.61  33.59  30.94  31.0000  101786600.0          0.0
# 2012-05-23  31.37  32.50  31.36  32.0000   73600000.0          0.0
# 2012-05-24  32.95  33.21  31.77  33.0300   50237200.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  \
# Date
# 2012-05-18          1.0      42.05      45.00     38.00     38.2318
# 2012-05-21          1.0      36.53      36.66     33.00     34.0300
# 2012-05-22          1.0      32.61      33.59     30.94     31.0000
# 2012-05-23          1.0      31.37      32.50     31.36     32.0000
# 2012-05-24          1.0      32.95      33.21     31.77     33.0300
#
#             Adj. Volume
# Date
# 2012-05-18  573576400.0
# 2012-05-21  168192700.0
# 2012-05-22  101786600.0
# 2012-05-23   73600000.0
# ...

# %%
boeing['Adj. Close'].plot(label="Boeing")  # plotting boeing data & labeling as such
walmart['Adj. Close'].plot(label="Walmart")  # plotting walmart data & labeling as such
tesla['Adj. Close'].plot(label="Tesla")  # plotting tesla data & labeling as such
facebook['Adj. Close'].plot(label="Facebook")  # plotting facebook data & labeling as such
plt.rcParams["figure.figsize"] = (20,10)  # customizing the graph where appropriate
plt.legend()
plt.title("Stock Price")
plt.ylabel("Price($)")
plt.show()  # showing output
